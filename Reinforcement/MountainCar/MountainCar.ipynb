# %% [markdown]
# In this tutorial we will try to learn DQN via MountainCar example

# %%
import gymnasium as gym
from gymnasium.utils.play import play

# https://github.com/openai/gym/issues/463

env = gym.make("MountainCar-v0", render_mode='rgb_array')
env.reset()
# Out:
# (array([-0.5889638,  0.       ], dtype=float32), {})

# %%
env.observation_space
# Out:
# Box([-1.2  -0.07], [0.6  0.07], (2,), float32)

# %%
env.action_space
# Out:
# Discrete(3)

# %%
env.step(0)
# Out:
# (array([-5.8947670e-01, -5.1289814e-04], dtype=float32),
#  -1.0,
#  False,
#  False,
#  {})

# %%
env.step(2)
# Out:
# (array([-0.5884987 ,  0.00097798], dtype=float32), -1.0, False, False, {})

# %% [markdown]
# Notice that we have maximum of 200 steps
